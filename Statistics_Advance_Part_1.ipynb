# %% [markdown]
# 1.  What is a random variable in probability theory
#
#   In probability theory, a random variable is a variable whose value is a numerical outcome of a random phenomenon. It's a function that assigns a numerical value to each possible outcome of a random experiment. Think of it as a way to quantify the results of a random event.
#
# 2. What are the types of random variables
#
#   There are two main types of random variables: discrete and continuous. Discrete random variables can only take on specific, countable values, while continuous random variables can take on any value within a given range.
#
# 3. What is the difference between discrete and continuous distributions
#
#   The main difference between discrete and continuous distributions lies in the nature of the variable they describe. Discrete distributions deal with countable, separate values, while continuous distributions deal with variables that can take on any value within a given range
#
# 4. What are probability distribution functions (PDF)
#
#   A probability distribution function (PDF) describes the likelihood of different outcomes for a continuous random variable. It essentially tells you how probable it is to find the variable within a specific range of values. For continuous variables, the PDF is a function that gives a value for the probability density at each point, and the probability of the variable falling within an interval is found by integrating the PDF over that interval.
#
# 5. > How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
#
#   A Probability Distribution Function (PDF) describes the likelihood of a random variable taking on a specific value, while a Cumulative Distribution Function (CDF) describes the probability that a random variable will be less than or equal to a specific value. In essence, the CDF accumulates the probabilities from the PDF up to a certain point.
#
# 6. What is a discrete uniform distribution)
#
#   A discrete uniform distribution is a probability distribution where a finite number of outcomes are all equally likely to occur. It's a simple distribution where each possible value within a defined range has the same probability of being selected.
#
# 7.  What are the key properties of a Bernoulli distribution
#
#   A Bernoulli distribution models a single trial with two possible outcomes: success (usually denoted as 1) or failure (usually denoted as 0). It is characterized by a single parameter, p, which represents the probability of success. Key properties include: binary outcomes, constant probability of success, independent trials, complementary probability of failure (1-p), being a discrete distribution, having a mean equal to p, and a variance of p(1-p)
#
# 8.  What is the binomial distribution, and how is it used in probability
#
#   What Is a Binomial Distribution?The binomial distribution is a discrete probability distribution that models the probability of achieving a specific number of successes in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure). It's frequently used to analyze scenarios like coin flips, quality control, and survey responses, where the outcome of each trial is binary.
#
# 9.  What is the Poisson distribution and where is it applied
#
#   The Poisson distribution is a discrete probability distribution that describes the probability of a given number of events occurring in a fixed interval of time or space, given that these events occur with a known average rate and independently of the time since the last event. It's used when dealing with rare events that happen randomly and independently over a period or area.
#
# 10. What is a continuous uniform distribution
#
#   A continuous uniform distribution is a probability distribution where a continuous random variable has an equal probability of taking any value within a specified range [a, b]. This means the probability density function (PDF) is constant within that range and zero outside of it. Essentially, every outcome within the range is equally likely to occur.
#
# 11. What are the characteristics of a normal distribution
#
#   A continuous uniform distribution is a probability distribution where a continuous random variable has an equal probability of taking any value within a specified range [a, b]. This means the probability density function (PDF) is constant within that range and zero outside of it. Essentially, every outcome within the range is equally likely to occur.
#
# 12. What is the standard normal distribution, and why is it important
#
#   The standard normal distribution is a specific type of normal distribution where the mean is 0 and the standard deviation is 1. It's a crucial concept in statistics because it allows us to compare data from different normal distributions and calculate probabilities related to those distributions.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics
#
#   What Is the Central Limit Theorem (CLT)?The Central Limit Theorem (CLT) states that the distribution of sample means will approximate a normal distribution, regardless of the original population's distribution, as long as the sample size is sufficiently large. This is critical in statistics because it allows us to make inferences about population parameters (like the mean) using sample data, even when the population distribution is unknown or non-normal.
#
# 14. How does the Central Limit Theorem relate to the normal distribution
#
#   The central limit theorem (CLT) explains the relationship between the normal distribution and sample means. It states that the distribution of sample means will approach a normal distribution, regardless of the shape of the original population distribution, as the sample size gets larger. In essence, the CLT provides a powerful tool for understanding and working with data by connecting the concept of sample means to the well-understood properties of the normal distribution.
#
# 15. What is the application of Z statistics in hypothesis testing
#
#   Z-statistics, calculated using a Z-test, are applied in hypothesis testing to determine if there's a significant difference between a sample's mean and a population's mean, or between the means of two independent samples. This is particularly useful when the population variance is known, or when dealing with large sample sizes (typically n ≥ 30).
#
# 16. > How do you calculate a Z-score, and what does it represent
#
#   A z-score measures how many standard deviations a data point is away from the mean of a dataset. It's calculated by subtracting the mean from the data point and dividing the result by the standard deviation. A positive z-score indicates the data point is above the mean, while a negative z-score indicates it's below the mean.
#
# 17. What are point estimates and interval estimates in statistics
#
#   In statistics, point estimates and interval estimates are two fundamental ways to estimate unknown population parameters using sample data. Point estimates provide a single value as the best guess, while interval estimates provide a range of values within which the parameter is likely to fall.
#
# 18. What is the significance of confidence intervals in statistical analysis
#
#   Confidence intervals in statistical analysis are crucial because they provide a range of plausible values for an unknown population parameter, offering a more informative measure of uncertainty than a single point estimate. They indicate the reliability and precision of an estimate and are essential for making data-driven decisions.
#
# 19. What is the relationship between a Z-score and a confidence interval
#
#   A Z-score is a measure of how many standard deviations a data point is from the mean, while a confidence interval provides a range of values within which a population parameter is likely to fall. The Z-score is used to determine the margin of error when constructing a confidence interval, particularly for large sample sizes or when the population standard deviation is known.
#
# 20. How are Z-scores used to compare different distributions
#
#   Z-scores are used to compare data from different distributions by standardizing the values. This means converting raw scores into a common scale based on standard deviations from the mean, allowing for direct comparison regardless of the original scale. A Z-score indicates how many standard deviations a data point is away from the mean of its distribution.
#
# 21. What are the assumptions for applying the Central Limit Theorem
#
#   The Central Limit Theorem (CLT) requires a few key assumptions to be met for the sampling distribution of sample means to approximate a normal distribution. These include: random sampling, independence of samples, a sufficiently large sample size, and sometimes, that the sample size is less than 10% of the population when sampling without replacement.
#
# 22. What is the concept of expected value in a probability distribution
#
#
#   The expected value in a probability distribution represents the long-run average outcome of a random variable. It's a weighted average of all possible values, where each value is weighted by its corresponding probability. Essentially, it tells you what you can "expect" to see, on average, if you repeat an experiment many times.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable
#
#   A probability distribution defines the likelihood of each possible outcome of a random variable, and the expected value is a way to summarize this distribution into a single, representative number. Specifically, the expected value represents the average outcome you would expect if you repeated the random experiment many times.

# %% [markdown]
#                                                  #####  Practical

# %%
import random

# Generate a random integer between 1 and 100 (inclusive)
random_variable = random.randint(1, 100)

# Display the value of the random variable
print(f"The generated random variable is: {random_variable}")
# Out:
# The generated random variable is: 7

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the discrete uniform distribution
lower_bound = 1
upper_bound = 10

# Number of random samples to generate
num_samples = 1000

# Generate random samples from a discrete uniform distribution
random_samples = np.random.randint(lower_bound, upper_bound + 1, size=num_samples)

# Calculate the frequency of each value
unique_values, counts = np.unique(random_samples, return_counts=True)

# Calculate the probability of each value (PMF)
probabilities = counts / num_samples

# Plot the Probability Mass Function (PMF)
plt.figure(figsize=(8, 6))
plt.bar(unique_values, probabilities, align='center', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability Mass Function of a Discrete Uniform Distribution')
plt.xticks(unique_values)
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 3.  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

# %%
def bernoulli_pdf(p, x):
  """
  Calculates the Probability Distribution Function (PDF) of a Bernoulli distribution.

  Args:
    p: The probability of success (a float between 0 and 1).
    x: The outcome (either 0 for failure or 1 for success).

  Returns:
    The probability of the given outcome.
  """
  if x == 1:
    return p
  elif x == 0:
    return 1 - p
  else:
    raise ValueError("Outcome x must be either 0 or 1")

# Example usage:
probability_of_success = 0.7
outcome_is_success = 1
outcome_is_failure = 0

pdf_success = bernoulli_pdf(probability_of_success, outcome_is_success)
pdf_failure = bernoulli_pdf(probability_of_success, outcome_is_failure)

print(f"The PDF for outcome 1 (success) with p={probability_of_success} is: {pdf_success}")
print(f"The PDF for outcome 0 (failure) with p={probability_of_success} is: {pdf_failure}")
# Out:
# The PDF for outcome 1 (success) with p=0.7 is: 0.7
# The PDF for outcome 0 (failure) with p=0.7 is: 0.30000000000000004

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5 # Probability of success

# Number of simulations
num_simulations = 1000

# Simulate the binomial distribution
binomial_samples = np.random.binomial(n, p, size=num_simulations)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(binomial_samples, bins=np.arange(-0.5, n + 1.5, 1), density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Number of Successes')
plt.ylabel('Probability Density')
plt.title(f'Simulated Binomial Distribution (n={n}, p={p})')
plt.xticks(np.arange(0, n + 1, 1))
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5 # Probability of success on each trial
num_samples = 1000 # Number of samples to generate for the simulation

# Simulate the binomial distribution
# np.random.binomial(n, p, size) generates 'size' number of samples
# where each sample represents the number of successes in 'n' trials
# with a probability of success 'p'.
binomial_samples = np.random.binomial(n, p, size=num_samples)

# Plot the histogram
plt.figure(figsize=(8, 6)) # Set the figure size for better visualization
plt.hist(binomial_samples, bins=np.arange(n + 2) - 0.5, edgecolor='black', alpha=0.7)
# bins are set to cover all possible outcomes (0 to n) and ensure clear separation
# edgecolor adds a border to the bars for better visibility
# alpha sets the transparency of the bars

plt.title(f'Histogram of Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n + 1)) # Ensure x-axis ticks are at integer values representing successes
plt.grid(axis='y', linestyle='--', alpha=0.7) # Add a horizontal grid for readability
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameter for the Poisson distribution (average rate of events)
lambda_param = 5

# Number of random samples to generate
num_samples = 1000

# Generate random samples from a Poisson distribution
poisson_samples = np.random.poisson(lambda_param, size=num_samples)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(poisson_samples, bins=np.arange(-0.5, max(poisson_samples) + 1.5, 1), density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Number of Events')
plt.ylabel('Probability Density')
plt.title(f'Simulated Poisson Distribution (λ={lambda_param})')
plt.xticks(np.arange(0, max(poisson_samples) + 1, 1))
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the discrete uniform distribution
lower_bound = 1
upper_bound = 10

# Generate possible values in the distribution
values = np.arange(lower_bound, upper_bound + 1)

# Calculate the probability of each value (for a discrete uniform distribution, it's equal for all values)
probability_per_value = 1 / len(values)

# Calculate the Cumulative Distribution Function (CDF)
# The CDF at a given value is the sum of probabilities of all values less than or equal to it.
cdf_values = [np.sum(probability_per_value for val in values if val <= x) for x in values]

# Plot the CDF
plt.figure(figsize=(8, 6))
plt.step(values, cdf_values, where='post')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of a Discrete Uniform Distribution')
plt.xticks(values)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# /tmp/ipython-input-8-1579921841.py:16: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   cdf_values = [np.sum(probability_per_value for val in values if val <= x) for x in values]

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the continuous uniform distribution
lower_bound = 0
upper_bound = 10

# Number of random samples to generate
num_samples = 10000

# Generate random samples from a continuous uniform distribution
continuous_samples = np.random.uniform(lower_bound, upper_bound, size=num_samples)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(continuous_samples, bins=50, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title(f'Simulated Continuous Uniform Distribution (range=[{lower_bound}, {upper_bound}])')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 8.  Simulate data from a normal distribution and plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for the normal distribution
mean = 0
std_dev = 1
num_samples = 1000

# Simulate data from a normal distribution
normal_samples = np.random.normal(mean, std_dev, num_samples)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(normal_samples, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title(f'Simulated Normal Distribution (Mean={mean}, Std Dev={std_dev})')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them>

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
  """
  Calculates Z-scores for a dataset and plots their distribution.

  Args:
    data: A list or NumPy array of numerical data.

  Returns:
    A NumPy array of calculated Z-scores.
  """
  # Calculate the mean and standard deviation of the dataset
  mean = np.mean(data)
  std_dev = np.std(data)

  # Calculate Z-scores for each data point
  z_scores = (data - mean) / std_dev

  # Plot the histogram of Z-scores
  plt.figure(figsize=(8, 6))
  plt.hist(z_scores, bins=30, density=True, alpha=0.7, edgecolor='black')
  plt.xlabel('Z-score')
  plt.ylabel('Probability Density')
  plt.title('Distribution of Z-scores')
  plt.grid(axis='y', linestyle='--')
  plt.show()

  return z_scores

# Example usage with a sample dataset
sample_data = np.array([10, 12, 15, 11, 13, 16, 14, 12, 10, 15, 25])
z_scores = calculate_and_plot_zscores(sample_data)

print("Calculated Z-scores:")
print(z_scores)
# Out:
# Calculated Z-scores:
# [-0.97475851 -0.47604486  0.27202563 -0.72540169 -0.22668803  0.52138246
#   0.0226688  -0.47604486 -0.97475851  0.27202563  2.76559393]

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %% [markdown]
# # Task
# Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution and visualize the distribution of sample means.

# %% [markdown]
# ## Choose a non-normal distribution
#
# ### Subtask:
# Select a suitable non-normal distribution to demonstrate the CLT (e.g., exponential, uniform, or a custom distribution).

# %% [markdown]
# **Reasoning**:
# Select the exponential distribution and define its parameter for the CLT demonstration.

# %%
# Choose a non-normal distribution: Exponential distribution
# Define the parameter for the exponential distribution (scale, which is 1/lambda)
scale_parameter = 2 # Example scale parameter

print(f"Chosen non-normal distribution: Exponential Distribution")
print(f"Parameter (scale) for the Exponential Distribution: {scale_parameter}")
# Out:
# Chosen non-normal distribution: Exponential Distribution
# Parameter (scale) for the Exponential Distribution: 2

# %% [markdown]
# ## Generate multiple samples
#
# ### Subtask:
# Generate a large number of random samples of a fixed size from the chosen non-normal distribution.

# %% [markdown]
# **Reasoning**:
# Generate a large number of random samples of a fixed size from the chosen non-normal distribution (Exponential distribution).

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
#
#   The Central Limit Theorem (CLT) can be demonstrated by simulating multiple samples from a distribution, calculating the mean of each sample, and observing that the distribution of these sample means tends towards a normal distribution, regardless of the original distribution's shape, provided the sample size is sufficiently large.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set parameters
num_samples = 10000
sample_size = 30
original_distribution_mean = 5
original_distribution_std = 2

# Create a normal distribution (as requested by the user)
original_distribution = np.random.normal(loc=original_distribution_mean, scale=original_distribution_std, size=num_samples)

# Store sample means
sample_means = []

# Simulate multiple samples and calculate their means
for _ in range(num_samples):
    # Generate a sample from the original distribution
    sample = np.random.choice(original_distribution, size=sample_size, replace=True)
    # Calculate the mean of the sample
    sample_mean = np.mean(sample)
    # Store the sample mean
    sample_means.append(sample_mean)

# Plot the original distribution and the distribution of sample means
plt.figure(figsize=(12, 5))

# Original distribution
plt.subplot(1, 2, 1)
plt.hist(original_distribution, bins=50, density=True, alpha=0.6, color='blue', label='Original Distribution (Normal)')
plt.title('Original Distribution (Normal)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Distribution of sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, density=True, alpha=0.6, color='red', label='Sample Means')
plt.title('Distribution of Sample Means (CLT)')
plt.xlabel('Mean Value')
plt.ylabel('Density')

# Overlay a normal distribution for comparison
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, 1/(np.std(sample_means) * np.sqrt(2 * np.pi)) * np.exp( - (x - np.mean(sample_means))**2 / (2 * np.std(sample_means)**2) ),
         linewidth=2, color='green', label='Normal Distribution')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 15.  Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
#
#   The Central Limit Theorem (CLT) can be demonstrated by simulating multiple samples from a distribution, calculating the mean of each sample, and observing that the distribution of these sample means tends towards a normal distribution, regardless of the original distribution's shape, provided the sample size is sufficiently large.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set parameters
num_samples = 10000
sample_size = 30
original_distribution_mean = 5
original_distribution_std = 2

# Create a skewed distribution (e.g., exponential)
# You can change this to other distributions (uniform, etc.)
original_distribution = np.random.exponential(scale=original_distribution_mean, size=num_samples)

# Store sample means
sample_means = []

# Simulate multiple samples and calculate their means
for _ in range(num_samples):
    # Generate a sample from the original distribution
    sample = np.random.choice(original_distribution, size=sample_size, replace=True)
    # Calculate the mean of the sample
    sample_mean = np.mean(sample)
    # Store the sample mean
    sample_means.append(sample_mean)

# Plot the original distribution and the distribution of sample means
plt.figure(figsize=(12, 5))

# Original distribution
plt.subplot(1, 2, 1)
plt.hist(original_distribution, bins=50, density=True, alpha=0.6, color='blue', label='Original Distribution')
plt.title('Original Distribution (e.g., Exponential)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Distribution of sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, density=True, alpha=0.6, color='red', label='Sample Means')
plt.title('Distribution of Sample Means (CLT)')
plt.xlabel('Mean Value')
plt.ylabel('Density')

# Overlay a normal distribution for comparison
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, 1/(np.std(sample_means) * np.sqrt(2 * np.pi)) * np.exp( - (x - np.mean(sample_means))**2 / (2 * np.std(sample_means)**2) ),
         linewidth=2, color='green', label='Normal Distribution')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
  """
  Calculates and plots the Probability Density Function (PDF)
  of the standard normal distribution (mean=0, std=1).
  """
  # Define the range of x values
  x = np.linspace(-4, 4, 100) # Typically plot from -4 to 4 standard deviations

  # Calculate the PDF of the standard normal distribution
  pdf_values = norm.pdf(x, loc=0, scale=1)

  # Plot the PDF
  plt.figure(figsize=(8, 6))
  plt.plot(x, pdf_values, linewidth=2, color='blue')
  plt.title('Standard Normal Distribution (Mean=0, Std Dev=1)')
  plt.xlabel('Z-score')
  plt.ylabel('Probability Density')
  plt.grid(True, linestyle='--', alpha=0.6)
  plt.show()

# Call the function to plot the standard normal distribution
plot_standard_normal_distribution()

# %% [markdown]
# 17. Generate random variables and calculate their corresponding probabilities using the binomial distribution5

# %%
import numpy as np
from scipy.stats import binom

# Define the parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5 # Probability of success on each trial

# Number of random variables to generate
num_random_variables = 5

# Generate random variables from the binomial distribution
random_variables = np.random.binomial(n, p, size=num_random_variables)

print(f"Generated random variables from Binomial({n}, {p}): {random_variables}")

# Calculate the probability of specific outcomes (e.g., the probabilities of the generated random variables)
print("\nProbabilities of the generated outcomes:")
for outcome in random_variables:
  probability = binom.pmf(outcome, n, p)
  print(f"P(X = {outcome}) = {probability:.4f}")

# You can also calculate the probability of other outcomes, for example:
specific_outcome = 7
probability_specific = binom.pmf(specific_outcome, n, p)
print(f"\nProbability of getting exactly {specific_outcome} successes in {n} trials with p={p}: {probability_specific:.4f}")
# Out:
# Generated random variables from Binomial(10, 0.5): [6 4 5 4 5]
#
# Probabilities of the generated outcomes:
# P(X = 6) = 0.2051
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
#
# Probability of getting exactly 7 successes in 10 trials with p=0.5: 0.1172

# %% [markdown]
# 18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
  """
  Calculates the Z-score for a given data point.

  Args:
    data_point: The individual data point.
    mean: The mean of the dataset.
    std_dev: The standard deviation of the dataset.

  Returns:
    The calculated Z-score.
  """
  z_score = (data_point - mean) / std_dev
  return z_score

# Example usage:
data_point = 18
mean = 15
std_dev = 3

z_score = calculate_z_score(data_point, mean, std_dev)

print(f"The data point {data_point} has a Z-score of: {z_score:.2f}")

# To compare it to a standard normal distribution, we can visualize it
# Plot the standard normal distribution
x = np.linspace(-4, 4, 100)
plt.figure(figsize=(8, 6))
plt.plot(x, norm.pdf(x, 0, 1), label='Standard Normal Distribution (PDF)')

# Mark the calculated Z-score on the plot
plt.axvline(z_score, color='red', linestyle='dashed', linewidth=2, label=f'Z-score = {z_score:.2f}')

plt.title('Comparison of Z-score to Standard Normal Distribution')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# You can also find the probability of getting a value less than or equal to this Z-score
cumulative_probability = norm.cdf(z_score)
print(f"The cumulative probability up to a Z-score of {z_score:.2f} is: {cumulative_probability:.4f}")
# Out:
# The data point 18 has a Z-score of: 1.00
# The cumulative probability up to a Z-score of 1.00 is: 0.8413

# %% [markdown]
# 19.  Implement hypothesis testing using Z-statistics for a sample dataset

# %% [markdown]
# # Task
# Implement hypothesis testing using Z-statistics for a sample dataset.

# %% [markdown]
# ## Formulate hypotheses
#
# ### Subtask:
# Define the null hypothesis ($H_0$) and the alternative hypothesis ($H_1$).

# %% [markdown]
# **Reasoning**:
# State the null and alternative hypotheses for a typical Z-test scenario.

# %%
# Define the null hypothesis (H0) and the alternative hypothesis (H1)

# Example Scenario: We want to test if the mean height of a sample of students
# is significantly different from the known population mean height.

# Null Hypothesis (H0): The mean height of the sample is equal to the population mean height.
# Mathematically: H0: μ = μ₀
# where μ is the sample mean and μ₀ is the population mean.

# Alternative Hypothesis (H1): The mean height of the sample is not equal to the population mean height.
# Mathematically: H1: μ ≠ μ₀
# This is a two-sided alternative hypothesis.

print("Null Hypothesis (H0): The mean of the sample is equal to the hypothesized population mean.")
print("Alternative Hypothesis (H1): The mean of the sample is not equal to the hypothesized population mean (two-sided test).")

# For a one-sided test (e.g., testing if the sample mean is greater than the population mean):
# Alternative Hypothesis (H1): The mean height of the sample is greater than the population mean height.
# Mathematically: H1: μ > μ₀

# For a one-sided test (e.g., testing if the sample mean is less than the population mean):
# Alternative Hypothesis (H1): The mean height of the sample is less than the population mean height.
# Mathematically: H1: μ < μ₀
# Out:
# Null Hypothesis (H0): The mean of the sample is equal to the hypothesized population mean.
# Alternative Hypothesis (H1): The mean of the sample is not equal to the hypothesized population mean (two-sided test).

# %% [markdown]
# ## Choose significance level
#
# ### Subtask:
# Determine the significance level ($\alpha$) for the test.

# %% [markdown]
# **Reasoning**:
# Choose a common significance level and assign it to a variable named `alpha`, then print the chosen significance level.

# %%
# Choose a significance level (alpha)
alpha = 0.05  # A common choice for alpha is 0.05

# Print the chosen significance level
print(f"The chosen significance level (alpha) is: {alpha}")
# Out:
# The chosen significance level (alpha) is: 0.05

# %% [markdown]
# ## Collect sample data
#
# ### Subtask:
# Obtain a sample dataset.

# %% [markdown]
# **Reasoning**:
# Generate a synthetic sample dataset as a NumPy array for demonstration purposes.

# %% [markdown]
# 20. Create a confidence interval for a dataset using Python and interpret the result5

# %% [markdown]
# # Task
# Create a confidence interval for a dataset using Python and interpret the result.

# %% [markdown]
# ## Collect sample data
#
# ### Subtask:
# Obtain or generate a sample dataset.

# %% [markdown]
# **Reasoning**:
# Generate a synthetic sample dataset as a NumPy array for demonstration purposes.

# %%
import numpy as np

# Generate a synthetic sample dataset
sample_data_for_ci = np.array([65, 68, 70, 71, 67, 69, 72, 70, 66, 69, 70, 71, 68, 67, 70])

# Display the sample data
print("Sample Dataset:")
print(sample_data_for_ci)
# Out:
# Sample Dataset:
# [65 68 70 71 67 69 72 70 66 69 70 71 68 67 70]

# %% [markdown]
# ## Calculate sample statistics
#
# ### Subtask:
# Calculate the sample mean ($\bar{x}$), sample standard deviation ($s$), and sample size ($n$).

# %% [markdown]
# **Reasoning**:
# Calculate the sample mean, sample standard deviation, and sample size from the generated sample data.

# %%
# Calculate the sample mean
sample_mean = np.mean(sample_data_for_ci)

# Calculate the sample standard deviation (using ddof=1 for sample standard deviation)
sample_std_dev = np.std(sample_data_for_ci, ddof=1)

# Determine the sample size
sample_size = len(sample_data_for_ci)

# Print the calculated values
print(f"Sample Mean (x̄): {sample_mean:.2f}")
print(f"Sample Standard Deviation (s): {sample_std_dev:.2f}")
print(f"Sample Size (n): {sample_size}")
# Out:
# Sample Mean (x̄): 68.87
# Sample Standard Deviation (s): 2.00
# Sample Size (n): 15

# %% [markdown]
# ## Choose confidence level
#
# ### Subtask:
# Determine the desired confidence level (e.g., 90%, 95%, 99%).

# %% [markdown]
# **Reasoning**:
# Choose a common confidence level and assign it to a variable, then print it.

# %%
# Choose the desired confidence level
confidence_level = 0.95  # 95% confidence level

# Print the chosen confidence level
print(f"Desired confidence level: {confidence_level}")
# Out:
# Desired confidence level: 0.95

# %% [markdown]
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

# %%
import numpy as np

# Define parameters for the normal distribution
mean = 50
std_dev = 10
sample_size = 100

# Generate data from a normal distribution
normal_data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Display the first few values of the generated data
print("Generated data from a normal distribution:")
print(normal_data[:10])
# Out:
# Generated data from a normal distribution:
# [40.21660177 42.24336621 60.94332959 63.62618042 59.28141133 53.17738858
#  63.89712164 41.42902756 55.0823858  47.37970802]

# %% [markdown]
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the parameters for the normal distribution
mean = 0
std_dev = 1

# Define the range of x values
x_values = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100) # Generate x values around the mean

# Calculate the Probability Density Function (PDF) for the normal distribution
pdf_values = norm.pdf(x_values, loc=mean, scale=std_dev)

# Plot the PDF
plt.figure(figsize=(8, 6))
plt.plot(x_values, pdf_values, linewidth=2, color='blue')
plt.title(f'Normal Distribution PDF (Mean={mean}, Std Dev={std_dev})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
from scipy.stats import poisson

# Define the parameter for the Poisson distribution (average rate of events)
lambda_param = 3

# Define a range of values for which to calculate the CDF
values_to_calculate_cdf = np.arange(0, 10) # Calculate CDF for values from 0 to 9

print(f"Calculating CDF for a Poisson distribution with lambda = {lambda_param}")

# Calculate the CDF for each value in the range
cdf_values = poisson.cdf(values_to_calculate_cdf, mu=lambda_param)

# Print the values and their corresponding CDF
print("\nValue | CDF")
print("------|------")
for value, cdf in zip(values_to_calculate_cdf, cdf_values):
  print(f"{value:<5} | {cdf:.4f}")

# Interpretation of the CDF:
print("\nInterpretation of the CDF:")
print(f"- The CDF at a specific value 'x' represents the probability of observing 'x' or fewer events in the given interval.")
print(f"- For example, the CDF at {values_to_calculate_cdf[2]} ({cdf_values[2]:.4f}) means there is a {cdf_values[2]:.2%} probability of observing {values_to_calculate_cdf[2]} or fewer events.")
print(f"- As the value of x increases, the CDF approaches 1, indicating that it becomes increasingly certain to observe a number of events less than or equal to that value.")
# Out:
# Calculating CDF for a Poisson distribution with lambda = 3
#
# Value | CDF
# ------|------
# 0     | 0.0498
# 1     | 0.1991
# 2     | 0.4232
# 3     | 0.6472
# 4     | 0.8153
# 5     | 0.9161
# 6     | 0.9665
# 7     | 0.9881
# 8     | 0.9962
# 9     | 0.9989
#
# Interpretation of the CDF:
# - The CDF at a specific value 'x' represents the probability of observing 'x' or fewer events in the given interval.
# - For example, the CDF at 2 (0.4232) means there is a 42.32% probability of observing 2 or fewer events.
# - As the value of x increases, the CDF approaches 1, indicating that it becomes increasingly certain to observe a number of events less than or equal to that value.

# %% [markdown]
# 24. 5 Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

# Define the range of the continuous uniform distribution [a, b]
a = 5
b = 15

# Simulate a single random variable from the continuous uniform distribution
random_variable = np.random.uniform(a, b)

print(f"Simulated random variable from a continuous uniform distribution between {a} and {b}: {random_variable:.4f}")

# Calculate the expected value of the continuous uniform distribution
# The formula for the expected value of a continuous uniform distribution is (a + b) / 2
expected_value = (a + b) / 2

print(f"Expected value of the continuous uniform distribution between {a} and {b}: {expected_value:.2f}")
# Out:
# Simulated random variable from a continuous uniform distribution between 5 and 15: 6.7607
# Expected value of the continuous uniform distribution between 5 and 15: 10.00

# %% [markdown]
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference5

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two sample datasets
dataset1 = np.random.normal(loc=10, scale=2, size=100) # Normal distribution with mean 10, std dev 2
dataset2 = np.random.normal(loc=10, scale=5, size=100) # Normal distribution with mean 10, std dev 5

# Calculate the standard deviations
std_dev1 = np.std(dataset1)
std_dev2 = np.std(dataset2)

print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

# Visualize the difference
labels = ['Dataset 1', 'Dataset 2']
std_devs = [std_dev1, std_dev2]

plt.figure(figsize=(8, 6))
plt.bar(labels, std_devs, color=['blue', 'red'])
plt.ylabel('Standard Deviation')
plt.title('Comparison of Standard Deviations of Two Datasets')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Optional: Visualize the distributions themselves to see the spread
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(dataset1, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')
plt.title('Distribution of Dataset 1')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
plt.hist(dataset2, bins=30, density=True, alpha=0.7, color='red', edgecolor='black')
plt.title('Distribution of Dataset 2')
plt.xlabel('Value')
plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 1.87
# Standard Deviation of Dataset 2: 5.39

# %% [markdown]
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
import numpy as np

# Define parameters for the normal distribution
mean = 50
std_dev = 10
sample_size = 100

# Generate data from a normal distribution
normal_data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate the range
data_range = np.max(normal_data) - np.min(normal_data)

# Calculate the Interquartile Range (IQR)
Q1 = np.percentile(normal_data, 25) # First quartile (25th percentile)
Q3 = np.percentile(normal_data, 75) # Third quartile (75th percentile)
iqr = Q3 - Q1

print(f"Generated dataset (first 10 values): {normal_data[:10]}")
print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr:.2f}")
# Out:
# Generated dataset (first 10 values): [57.36464192 57.85882927 36.32843078 49.61510726 61.34044453 61.68687166
#  38.3034777  32.86679794 52.65226142 61.61311782]
# Range of the dataset: 54.17
# Interquartile Range (IQR) of the dataset: 13.33

# %% [markdown]
# 27. Implement Z-score normalization on a dataset and visualize its transformation

# %% [markdown]
# # Task
# Implement Z-score normalization on a dataset and visualize its transformation

# %% [markdown]
# ## Generate or obtain a dataset
#
# ### Subtask:
# Create or load a dataset that you want to normalize.

# %% [markdown]
# **Reasoning**:
# Generate a synthetic dataset using numpy.random.rand and store it in a NumPy array named original_dataset.

# %%
import numpy as np

# Generate a synthetic dataset with a size of 100
original_dataset = np.random.rand(100)

# Display the first few values of the generated dataset
print("Original Dataset (first 10 values):")
print(original_dataset[:10])
# Out:
# Original Dataset (first 10 values):
# [0.16996736 0.02077757 0.71304447 0.17828973 0.6205267  0.09410976
#  0.57649592 0.2580527  0.88195379 0.78958146]

# %% [markdown]
# ## Calculate mean and standard deviation
#
# ### Subtask:
# Calculate the mean and standard deviation of the original dataset.

# %% [markdown]
# **Reasoning**:
# Calculate the mean and standard deviation of the original dataset.

# %%
# Calculate the mean of the original dataset
mean_original = np.mean(original_dataset)

# Calculate the standard deviation of the original dataset
std_dev_original = np.std(original_dataset)

# Print the calculated mean and standard deviation
print(f"Mean of the original dataset: {mean_original:.4f}")
print(f"Standard deviation of the original dataset: {std_dev_original:.4f}")
# Out:
# Mean of the original dataset: 0.4922
# Standard deviation of the original dataset: 0.2740

# %% [markdown]
# **Reasoning**:
# Apply the Z-score normalization formula to each data point in the original dataset to create the normalized dataset, then print the first few normalized values.

# %%
# Apply Z-score normalization
# The formula for Z-score is (x - mean) / standard deviation
normalized_dataset = (original_dataset - mean_original) / std_dev_original

# Display the first few values of the normalized dataset
print("Normalized Dataset (first 10 values):")
print(normalized_dataset[:10])
# Out:
# Normalized Dataset (first 10 values):
# [-1.17619072 -1.72075586  0.80612226 -1.14581281  0.4684185  -1.45308236
#   0.30769955 -0.85466602  1.42266663  1.08549374]

# %% [markdown]
# **Reasoning**:
# Plot the distribution of the original and normalized datasets side-by-side to visualize the transformation.

# %%
import matplotlib.pyplot as plt

# Visualize the original and normalized datasets
plt.figure(figsize=(12, 5))

# Plot the histogram of the original dataset
plt.subplot(1, 2, 1)
plt.hist(original_dataset, bins=20, density=True, alpha=0.7, color='blue', edgecolor='black')
plt.title('Original Dataset Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot the histogram of the normalized dataset
plt.subplot(1, 2, 2)
plt.hist(normalized_dataset, bins=20, density=True, alpha=0.7, color='red', edgecolor='black')
plt.title('Normalized Dataset Distribution (Z-scores)')
plt.xlabel('Z-score')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Verify mean and standard deviation of normalized data
#
# ### Subtask:
# Optionally, calculate the mean and standard deviation of the normalized dataset to confirm they are close to 0 and 1, respectively.

# %% [markdown]
# **Reasoning**:
# Calculate and print the mean and standard deviation of the normalized dataset to verify the Z-score transformation.

# %% [markdown]
# 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
  """
  Calculates the skewness and kurtosis of a dataset.

  Args:
    data: A NumPy array of numerical data.

  Returns:
    A tuple containing the skewness and kurtosis of the dataset.
  """
  # Calculate skewness
  data_skewness = skew(data)

  # Calculate kurtosis
  data_kurtosis = kurtosis(data) # By default, this is the excess kurtosis (kurtosis - 3)

  return data_skewness, data_kurtosis

# Generate a dataset from a normal distribution
mean = 0
std_dev = 1
sample_size = 1000
normal_data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate skewness and kurtosis for the normal dataset
skewness_normal, kurtosis_normal = calculate_skewness_kurtosis(normal_data)

print(f"Skewness of the normal dataset: {skewness_normal:.4f}")
print(f"Kurtosis of the normal dataset: {kurtosis_normal:.4f}")

# Example with a non-normal dataset (e.g., exponential)
exponential_data = np.random.exponential(scale=1, size=1000)
skewness_exp, kurtosis_exp = calculate_skewness_kurtosis(exponential_data)

print(f"\nSkewness of the exponential dataset: {skewness_exp:.4f}")
print(f"Kurtosis of the exponential dataset: {kurtosis_exp:.4f}")
# Out:
# Skewness of the normal dataset: -0.0264
# Kurtosis of the normal dataset: 0.3187
#
# Skewness of the exponential dataset: 2.1477
# Kurtosis of the exponential dataset: 7.1883
